# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = -1     #Acceleration is negative
v = 5      # Stone thrown up so positive
x = 0      # Thrown from the ground (0)
dt = 0.01  # numerical integration step is supposed to be small
nsteps = 1000
history = np.zeros(nsteps)   # eventually will be plotted
for i in range(nsteps):
    v = v + a*dt
    x = x + v*dt
    history[i] = x
    
plt.plot(history);

# %%
a = -1     #Acceleration is negative
vy = 5      # Stone thrown up so positive
vx = 1      # Thrown as far as possible
y = 0
x = 0
dt = 0.05  # numerical integration step is supposed to be small
nsteps = 1000

history = np.zeros(nsteps)   # eventually will be plotted
for i in range(nsteps):
    vy = vy + a*dt
    x = x + vx*dt
    y = max(y + vy*dt,0)
    plt.plot(x,y,'k.');

# %%
#Arseny's
a = -1        # Acceleratiion; negative coz it tries to reverse the flight of the stone
vy = 5        # Vertical component of the speed, and it's upwards => positive
vx = 1        # Horizontal component of the speed
x = 0         # We throw it from our house, and are trying to see how far it goes
y = 0         # We throw it from the surface, so y=0
dt = 0.01     # Our step. Numerical integration step. Is supposed to be small.
nsteps = round(10/dt)

for i in range(nsteps):
    vy = (vy + a*dt)      # Update vertical speed
    
    x = x + vx*dt           # Update x position
    y = max(y + vy*dt , 0)  # Update y position
    
    plt.plot(x,y,'k.');      # Just plot a new point, instead of remembering x and y, coz we're lazy right now

# %%
#Arseny's with friction
a = -1        # Acceleratiion; negative coz it tries to reverse the flight of the stone
vy = 5        # Vertical component of the speed, and it's upwards => positive
vx = 1        # Horizontal component of the speed
x = 0         # We throw it from our house, and are trying to see how far it goes
y = 0         # We throw it from the surface, so y=0
dt = 0.01     # Our step. Numerical integration step. Is supposed to be small.
f = 0.1
nsteps = round(10/dt)

for i in range(nsteps):
    vy = (vy + a*dt) - vy*f     # Update vertical speed
    vx = vx - vx*f
    x = x + vx*dt           # Update x position
    y = max(y + vy*dt , 0)  # Update y position
    
    plt.plot(x,y,'k.');      # Just plot a new point, instead of remembering x and y, coz we're lazy right now

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#exponential
nsteps = 100
x = np.zeros(nsteps) # of animals at each step
x[0] = 1     # original number of animals
r = 1.1     # rate of change

for i in range(1,nsteps):
    x[i] = x[i-1]*r
    
    plt.plot(x)

# %%
# logistic growth model

nsteps = 100
x = np.zeros(nsteps) # of animals at each step
x[0] = 0.8   # original number of animals
r = 3.9     # rate of change  
fig = plt.

for i in range(1,nsteps):
    x[i] = r*x[i-1]*(1-x[i-1])
    
    plt.plot(x);
    plt.ylim(0,1) # force y axis to be between 0 and 1
