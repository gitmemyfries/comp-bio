# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 100
r = 1
x = 0.6
i = 0
figure = plt.figure()

for r in np.arange(2,4,0.001):   
    i = i+1
    for j in range(nsteps+(i%50)):
        x = x*r*(1-x)
    plt.plot(r,x,'k.',markersize=1)

# %%
nsteps = 100              # Number of steps in our lil simulation
x = np.zeros(shapes(=nsteps,ntraces)      # Number of animals at every step
x[0] = 0.6                # The original "population size"
r = 3.9                   # Rate of population change (groth - die-out?)
             
             
for i in range(1,nsteps):
    x[i] = r*x[i-1]*(1-x[i-1])
     
plt.plot(x);
plt.ylim((0,1)) # Force y axis to be between 0 and 1
# Out:
# (0, 1)
